# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
# read the data
df_ori = pd.read_csv('movies.csv')

# %%
df_ori.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# check missing data
for col in df_ori.columns:
    pct_missing = np.mean(df_ori[col].isnull()) # percentage of missing value for every colmn
    print('{}-{}%'.format(col, pct_missing))
# Out:
# name-0.0%
# rating-0.010041731872717789%
# genre-0.0%
# year-0.0%
# released-0.0002608242044861763%
# score-0.0003912363067292645%
# votes-0.0003912363067292645%
# director-0.0%
# writer-0.0003912363067292645%
# star-0.00013041210224308815%
# country-0.0003912363067292645%
# budget-0.2831246739697444%
# gross-0.02464788732394366%
# company-0.002217005738132499%
# runtime-0.0005216484089723526%

# %%
# remove the missing rows that contain missing data 
df = df_ori.dropna()
print(len(df)/len(df_ori))

#about 71% data remains
# Out:
# 0.706964006259781

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#change datatype to interger
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
# Out:
# /var/folders/vl/v05_qs7d0xb5x_5stnfx3my40000gn/T/ipykernel_1578/1883358687.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['budget'] = df['budget'].astype('int64')
# /var/folders/vl/v05_qs7d0xb5x_5stnfx3my40000gn/T/ipykernel_1578/1883358687.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gross'] = df['gross'].astype('int64')

# %%
# create correct year column
# ([0-9]{4})为正则表达式 Regular expression
df['yearcorrect'] = df['released'].str.extract(pat='([0-9]{4})').astype(int)
df
# Out:
# /var/folders/vl/v05_qs7d0xb5x_5stnfx3my40000gn/T/ipykernel_1578/2574306581.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['yearcorrect'] = df['released'].str.extract(pat='([0-9]{4})').astype(int)
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# ...

# %%
# drop the 'year' column and rename 'yearcorrect' to 'year'
df = df.drop('year', axis=1)
df.rename(columns={'yearcorrect': 'year'}, inplace=True)

# %%
# sort 
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# drop duplicates
df.drop_duplicates()
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
# ...

# %%
# scatter plot with budget VS gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budgets VS Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# plot the budget VS gross using seaborn

sns.regplot(x='budget', y='gross', data=df,
            scatter_kws={'color':'red'},
            line_kws={'color':'blue'}
           )
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# looking at correlation

df.corr()
# Out:
#             score     votes    budget     gross   runtime      year
# score    1.000000  0.474256  0.072001  0.222556  0.414068  0.061923
# votes    0.474256  1.000000  0.439675  0.614751  0.352303  0.203098
# budget   0.072001  0.439675  1.000000  0.740247  0.318695  0.320312
# gross    0.222556  0.614751  0.740247  1.000000  0.275796  0.268721
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000  0.075294
# year     0.061923  0.203098  0.320312  0.268721  0.075294  1.000000

# %%
# high correlation between budget and gross
# correlation matrix
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('correlation matrix for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
# look at the non-numeric fearures
# change the non-numeric fearures to numeric
df_numerized = df
for col_name in df_numerized.columns:
    if df_numerized[col_name].dtype == 'object':
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        # Series.cat.codes: Return Series of codes as well as the index.
        # The categorical type is a process of factorization. 
        # Meaning that each unique value or category is given a incremented integer value starting from zero.

df_numerized
# Out:
#       name  rating  genre  released  score      votes  director  writer  star  \
# 0     4692       6      6      1304    8.4   927000.0      1795    2832   699
# 1     3929       6      1      1127    5.8    65000.0      1578    1158   214
# 2     3641       4      0      1359    8.7  1200000.0       757    1818  1157
# 3      204       4      4      1127    7.7   221000.0       889    1413  1474
# 4      732       6      4      1170    7.3   108000.0       719     351   271
# ...    ...     ...    ...       ...    ...        ...       ...     ...   ...
# 7648   415       6      0       904    6.6   140000.0        16    2390  1812
# 7649  3556       4      0       713    6.5   102000.0       852    2309   147
# 7650  1153       4      1       904    5.6    53000.0      1809    2827  1470
# 7651  3978       4      1       758    6.8    42000.0       294    2091   640
# 7652  4090       3      0       370    6.8     3700.0       746    1184  1839
#
# ...

# %%
correlation_matrix = df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('correlation matrix for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
print(corr_pairs)
# Out:
# name  name        1.000000
#       rating     -0.029234
#       genre       0.010996
#       released   -0.006152
#       score       0.014450
#                     ...
# year  budget      0.320312
#       gross       0.268721
#       company    -0.018806
#       runtime     0.075294
#       year        1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget    genre      -0.368523
# genre     budget     -0.368523
#           gross      -0.244101
# gross     genre      -0.244101
# rating    budget     -0.203946
#                         ...
# released  released    1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# runtime   runtime     1.000000
# year      year        1.000000
# Length: 225, dtype: float64

# %%
high_corr = sorted_pairs[sorted_pairs > 0.5]
high_corr
# Out:
# votes     gross       0.614751
# gross     votes       0.614751
# budget    gross       0.740247
# gross     budget      0.740247
# name      name        1.000000
# writer    writer      1.000000
# company   company     1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# director  director    1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# runtime   runtime     1.000000
# year      year        1.000000
# dtype: float64

# %%
# budget and gross have the highest correlarion
